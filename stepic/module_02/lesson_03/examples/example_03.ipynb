# %%
import pylab as pl

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pl.figure(figsize=(15, 15))
pl.scatter([0, 3, 2, 1.5], [3, 3, 3, 2], s=150, color="b", alpha=0.6)
pl.scatter([-1, -1, -2], [-0.5, -1, -2], s=150, color="r", alpha=0.6)
pl.scatter([2], [-1], s=150, color="g", alpha=0.6)
pl.gca().xaxis.set_ticklabels([])
pl.gca().yaxis.set_ticklabels([])
pl.grid()
pl.show()

# %%
import math
math.sqrt(1 + 1.5**2)
# Out:
# 1.8027756377319946
