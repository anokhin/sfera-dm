# %%
import pylab as pl
import numpy as np
import seaborn as sns

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
X = np.array([np.random.lognormal(size=100), np.random.uniform(size=100)]).T

# %%
pl.figure(figsize=(5,5))
pl.scatter(X[:, 0], X[:, 1], color="red")
pl.title("Original")
pl.show()

# %%
pl.figure(figsize=(5,5))
pl.scatter((X[:, 0] - X[:, 0].min()) / (X[:, 0].max() - X[:, 0].min()), X[:, 1], color="blue")
pl.title("Normalized")
pl.show()

# %%
pl.figure(figsize=(5,5))
pl.scatter((X[:, 0] - X[:, 0].mean()) / (X[:, 0].std()), X[:, 1], color="blue")
pl.title("Standartized")
pl.show()

# %%
pl.figure(figsize=(5,5))
pl.scatter(np.log(X[:, 0]), X[:, 1], color="blue")
pl.title("Log")
pl.show()

# %%
pl.figure(figsize=(5,5))
pl.scatter(np.sqrt(X[:, 0]), X[:, 1], color="blue")
pl.title("SQRT")
pl.show()
