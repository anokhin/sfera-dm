# %%
import numpy as np
import pylab as pl

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pl.figure(figsize=(8, 8))
pl.scatter(
    [2, 1, 2, 3, 6, 7, 7, 6.5, 4],
    [7, 7, 6, 8, 5, 4, 7, 4.5, 1]
)
pl.xlim(0, 9)
pl.ylim(0, 9)
pl.grid()
